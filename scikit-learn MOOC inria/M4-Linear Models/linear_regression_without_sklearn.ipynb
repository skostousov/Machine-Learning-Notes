# %%
import pandas as pd

penguins = pd.read_csv("penguins_regression.csv")
penguins.head()
# Out:
#    Flipper Length (mm)  Body Mass (g)
# 0                181.0         3750.0
# 1                186.0         3800.0
# 2                195.0         3250.0
# 3                193.0         3450.0
# 4                190.0         3650.0

# %%
import seaborn as sns

feature_name = "Flipper Length (mm)"
target_name = "Body Mass (g)"
data, target = penguins[[feature_name]], penguins[target_name]

ax = sns.scatterplot(
    data=penguins, x=feature_name, y=target_name, color="black", alpha=0.5
)
#returns matpplot lib axis qwhich can be furhter modified via adding of title, etc.
ax.set_title("Body Mass as a function of the Flipper Length")
# Out:
# Text(0.5, 1.0, 'Body Mass as a function of the Flipper Length')

# %%
def linear_model_flipper_mass(
        flipper_length, a, b
):
    """Linear model of the form y = a*x + b"""
    body_mass = a * flipper_length + b
    return body_mass

# %%
import numpy as np

a = 45
b = -5000

flipper_length_range = np.linspace(data.min(), data.max(), num=300)
predicted_body_mass = linear_model_flipper_mass(
    flipper_length_range, a, b
)

# %%
label = "{0:.2f} (g / mm) * flipper length + {1:.2f} (g)"

ax = sns.scatterplot(
    data=penguins, x=feature_name, y= target_name, color="black", alpha=0.5
)
ax.plot(flipper_length_range, predicted_body_mass)
_ = ax.set_title(label.format(a, b))
